# %%
### Requirements ### 
import pandas as pd
import numpy as np 
import time
import sys

import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime, timedelta 
from pycoingecko import CoinGeckoAPI

# %% [markdown]
# **Read watchlist**

# %%
main_ids = pd.read_csv('main50.csv', index_col = 'Unnamed: 0')

# %% [markdown]
# * We will create a **database** to store **time series** for **20 different metrics** for eachone off all 50 projects.
# * We will collect **3 years worth of daily data**, save it as a **CSV file**, and **transfer to Cloud Storage** as an initial data feed.

# %% [markdown]
# ---

# %% [markdown]
# # Collect and Store
# ## 1st step | Network historical data range, 3 years
#
# ### Defining network range function
# * **Approach 1** | Test for 1 id
# * **Objectives** | create time seried dataframe for community, development and market daily metrics.

# %%
def tsMaker(id, days):
    '''
    Takes an id, request up to 100 days/min worthy of social media and github data from coingeckoAPI().
    
    : chartMaker('bitcoin', 10)
    > df([columns], index = days range)
    '''
    
    # set social media appendable lists
    twitter_foll_list        = []
    reddit_subs_list         = [] 
    reddit_avg_posts_list    = []
    reddit_avg_comments_list = []
    
    # set developers appendable lists
    forks_list          = []
    stars_list          = []
    subscribers_list    = []
    total_issues_list   = []
    closed_issues_list  = []
    pull_rqst_merg_list = []
    pull_rqst_cont_list = []
    
    # set current_price appendable lists   
    usd_cp_list = []
    eur_cp_list = []
    brl_cp_list = []

    # set market_cap appendable lists   
    usd_mc_list = []
    eur_mc_list = []
    brl_mc_list = [] 
    
    # set total_volume appendable lists   
    usd_tv_list = []
    eur_tv_list = []
    brl_tv_list = []
    
    # date range (days serie, ascending)
    today = datetime.now() - timedelta(days = 1) # Feb, 22, 2022. 
    dates = pd.Series([(today - timedelta(days = x)).strftime('%d-%m-%Y') for x in range(days)])
    
    # Set variables
    cg = CoinGeckoAPI()
    x  = 1
    
    for date in dates:
        while True:
            #try request
            try:
                request_dict = cg.get_coin_history_by_id(id = id, date = date)
                
            # Handle error
            except Exception as error:
                
                # Communicate error and handle
                print(f'{error} \nProgram will wait for a minute and try again. \n')
                time.sleep(70)
                continue
                
            # if no error, break while loop, continue 
            break
        
        ########################## get community data ###########################################
        # Try to request community data, if it doesn't exist, retriavable dates ended
        
        try:
            rqst_community_data = request_dict['community_data']

        # Handle error
        except Exception as error:
            if x is 1:
                print(f'{error} | {id} has no community data for {date}. Filling missing values with None.')
                rqst_community_data = request_dict_copy = {'community_data':{
                                    'twitter_followers': None,
                                    'reddit_average_posts_48h': 0.0,
                                    'reddit_average_comments_48h': 0.0,
                                    'reddit_subscribers': 0.0,
                                    'reddit_accounts_active_48h': '0.0'}} 
                
            else:
                print(f'{error} | {id} has no community data before {date}. Breaking loop.')
                break
                

        # If looping hasn't been broken, proceed 
        twitter_foll            = rqst_community_data.get('twitter_followers')
        reddit_subs             = rqst_community_data.get('reddit_subscribers')
        reddit_avg_posts_48h    = rqst_community_data.get('reddit_average_posts_48h')
        reddit_avg_comments_48h = rqst_community_data.get('reddit_average_comments_48h')
    
        # append to community lists
        twitter_foll_list.append(twitter_foll)
        reddit_subs_list.append(reddit_subs)
        reddit_avg_posts_list.append(reddit_avg_posts_48h)
        reddit_avg_comments_list.append(reddit_avg_comments_48h)
            
        ########################## get developing data ##########################################
        rqst_developer_data       = request_dict['developer_data']
        
        forks                     = rqst_developer_data.get('forks')
        stars                     = rqst_developer_data.get('stars')
        subscribers               = rqst_developer_data.get('subscribers')
        total_issues              = rqst_developer_data.get('total_issues')
        closed_issues             = rqst_developer_data.get('closed_issues')
        pull_rqst_merged          = rqst_developer_data.get('pull_requests_merged')
        pull_request_contributors = rqst_developer_data.get('pull_request_contributors')
        
        # append to developer lists
        forks_list.append(forks)
        stars_list.append(stars)
        subscribers_list.append(subscribers)
        total_issues_list.append(total_issues)
        closed_issues_list.append(closed_issues)
        pull_rqst_merg_list.append(pull_rqst_merged)
        pull_rqst_cont_list.append(pull_request_contributors)
        
        
        ######################### get current price data ##########################################
        rqst_price_data   = request_dict['market_data']['current_price']
        
        usd_current_price = rqst_price_data.get('usd')
        eur_current_price = rqst_price_data.get('eur')
        brl_current_price = rqst_price_data.get('brl')
        
        # append to current_price_lists lists
        usd_cp_list.append(usd_current_price)
        eur_cp_list.append(eur_current_price)
        brl_cp_list.append(brl_current_price)
                
        
        ########################## get market cap data ###########################################
        rqst_mktcap_data = request_dict['market_data']['market_cap']

        usd_market_cap   = rqst_mktcap_data.get('usd')
        eur_market_cap   = rqst_mktcap_data.get('eur')
        brl_market_cap   = rqst_mktcap_data.get('brl')
        
        # append to current_price_lists lists
        usd_mc_list.append(usd_market_cap)
        eur_mc_list.append(eur_market_cap)
        brl_mc_list.append(brl_market_cap)
        
        ######################### get total volume data ##########################################
        rqst_volume_data = request_dict['market_data']['total_volume']

        usd_total_volume = rqst_volume_data.get('usd')
        eur_total_volume = rqst_volume_data.get('eur')
        brl_total_volume = rqst_volume_data.get('brl')
        
        # append to current_price_lists lists
        usd_tv_list.append(usd_total_volume)
        eur_tv_list.append(eur_total_volume)
        brl_tv_list.append(brl_total_volume)
        
        # Set list of lists for error handling 
        lst_lst = [twitter_foll_list, reddit_subs_list ,reddit_avg_posts_list ,reddit_avg_comments_list,
               forks_list, stars_list, subscribers_list, total_issues_list, closed_issues_list,
               pull_rqst_merg_list, pull_rqst_cont_list, usd_cp_list, eur_cp_list,
               brl_cp_list, usd_mc_list, eur_mc_list, brl_mc_list,
               usd_tv_list, eur_tv_list, brl_tv_list]
        
        # Add to x
        x+=1
        
        # Communicate
        if len(twitter_foll_list)%100==0:
            print(f'{len(twitter_foll_list)} days processed')
        
    
    #create empty list for unavailable data
    empty_lst    = [np.nan for i in range(0,(days-x))]
        
    #condition to append
    if len(empty_lst)>0:
        
        # Append empty_lst to filled metrics lists
        lst_lst  = [(lst+empty_lst) for lst in lst_lst]
    
    # Set dataframe using the lists
    extracted_df = pd.DataFrame({
                               # Community data
                               'twitter_followers':lst_lst[0],
                               'reddit_subs':lst_lst[1],
                               'reddit_avg_posts_48h':lst_lst[2],
                               'reddit_avg_comments_48h':lst_lst[3],
                               
                               # developer data        
                               'forks':lst_lst[4],
                               'stars':lst_lst[5],
                               'github_subs':lst_lst[6],
                               'total_issues':lst_lst[7],
                               'closed_issues':lst_lst[8],
                               'pull_rqst_merged':lst_lst[9],
                               'pull_request_contributors':lst_lst[10],
                                
                               # current_price data
                               'usd_cp':lst_lst[11],
                               'eur_cp':lst_lst[12],
                               'brl_cp':lst_lst[13],
        
                               # Market_cap data
                               'usd_mc':lst_lst[14],
                               'eur_mc':lst_lst[15],
                               'brl_mc':lst_lst[16],
        
                               # total_volume data
                               'usd_tv':lst_lst[17],
                               'eur_tv':lst_lst[18],
                               'brl_tv':lst_lst[19]},
                            
                               # Indexing 
                               index = dates)
    
        
    # Rounding lists
    round_zero_list = ['twitter_followers','reddit_subs',
                       'forks','stars','github_subs',
                       'total_issues','closed_issues',
                       'pull_rqst_merged','pull_request_contributors',
                       'usd_mc', 'eur_mc', 'brl_mc',
                       'usd_tv', 'eur_tv', 'brl_tv']
    round_two_list = [col for col in extracted_df.columns if col not in round_zero_list]
    
    # Rounding
    extracted_df[round_zero_list] = round(extracted_df[round_zero_list])
    extracted_df[round_two_list] = round(extracted_df[round_two_list],2)
    
    # Communicate
    print(f'All done for {id}.')
    

    return extracted_df

# %% [markdown]
# # Pull all

# %%
def extractAll(ids):
    
    # loop through all ids
    for id in ids:
        # extract time series
        df = tsMaker(id, 1096)
        
        # upload as csv
        df.to_csv(f'{id}_daily_data.csv')
    
    return df

# %% [markdown]
# #### For real

# %%
sizes = extractAll(main_ids)
# Out:
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/electroneum/history?date=08-12-2021
# Program will wait for a minute and try again.
#
# 100 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/electroneum/history?date=02-10-2021
# Program will wait for a minute and try again.
#
# 200 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/electroneum/history?date=12-07-2021
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/electroneum/history?date=08-05-2021
# Program will wait for a minute and try again.
#
# 300 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/electroneum/history?date=26-02-2021
# Program will wait for a minute and try again.
#
# 400 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/electroneum/history?date=05-12-2020
# Program will wait for a minute and try again.
#
# 500 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/electroneum/history?date=30-09-2020
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/electroneum/history?date=22-07-2020
# Program will wait for a minute and try again.
#
# 600 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/electroneum/history?date=07-05-2020
# Program will wait for a minute and try again.
#
# 700 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/electroneum/history?date=24-02-2020
# Program will wait for a minute and try again.
#
# 800 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/electroneum/history?date=15-12-2019
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/electroneum/history?date=05-10-2019
# Program will wait for a minute and try again.
#
# 900 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/electroneum/history?date=18-07-2019
# Program will wait for a minute and try again.
#
# 1000 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/electroneum/history?date=01-05-2019
# Program will wait for a minute and try again.
#
# All done for electroneum.
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/tornado-cash/history?date=06-02-2022
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/tornado-cash/history?date=23-11-2021
# Program will wait for a minute and try again.
#
# 100 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/tornado-cash/history?date=15-09-2021
# Program will wait for a minute and try again.
#
# 200 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/tornado-cash/history?date=06-07-2021
# Program will wait for a minute and try again.
#
# 300 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/tornado-cash/history?date=17-04-2021
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/tornado-cash/history?date=09-02-2021
# Program will wait for a minute and try again.
#
# 'community_data' | tornado-cash has no community data before 07-02-2021. Breaking loop.
# All done for tornado-cash.
# /Users/gabrielgomes/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:10720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   **kwargs,
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/platon-network/history?date=14-12-2021
# Program will wait for a minute and try again.
#
# 100 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/platon-network/history?date=28-09-2021
# Program will wait for a minute and try again.
#
# 200 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/platon-network/history?date=23-07-2021
# Program will wait for a minute and try again.
#
# 'community_data' | platon-network has no community data before 11-05-2021. Breaking loop.
# All done for platon-network.
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/eos/history?date=18-02-2022
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/eos/history?date=11-12-2021
# Program will wait for a minute and try again.
#
# 100 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/eos/history?date=29-09-2021
# Program will wait for a minute and try again.
#
# 200 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/eos/history?date=07-07-2021
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/eos/history?date=03-05-2021
# Program will wait for a minute and try again.
#
# 300 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/eos/history?date=18-02-2021
# Program will wait for a minute and try again.
#
# 400 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/eos/history?date=08-12-2020
# Program will wait for a minute and try again.
#
# 500 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/eos/history?date=14-09-2020
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/eos/history?date=06-07-2020
# Program will wait for a minute and try again.
#
# 600 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/eos/history?date=27-04-2020
# Program will wait for a minute and try again.
#
# 700 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/eos/history?date=07-02-2020
# Program will wait for a minute and try again.
#
# 800 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/eos/history?date=04-12-2019
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/eos/history?date=19-09-2019
# Program will wait for a minute and try again.
#
# 900 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/eos/history?date=11-07-2019
# Program will wait for a minute and try again.
#
# 1000 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/eos/history?date=01-05-2019
# Program will wait for a minute and try again.
#
# All done for eos.
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/coin98/history?date=11-02-2022
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/coin98/history?date=01-12-2021
# Program will wait for a minute and try again.
#
# 100 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/coin98/history?date=20-09-2021
# Program will wait for a minute and try again.
#
# 200 days processed
# 'community_data' | coin98 has no community data before 22-07-2021. Breaking loop.
# All done for coin98.
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/solana/history?date=08-02-2022
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/solana/history?date=25-11-2021
# Program will wait for a minute and try again.
#
# 100 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/solana/history?date=18-09-2021
# Program will wait for a minute and try again.
#
# 200 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/solana/history?date=29-06-2021
# Program will wait for a minute and try again.
#
# 300 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/solana/history?date=28-04-2021
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/solana/history?date=16-02-2021
# Program will wait for a minute and try again.
#
# 400 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/solana/history?date=13-12-2020
# Program will wait for a minute and try again.
#
# 500 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/solana/history?date=03-10-2020
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/solana/history?date=11-07-2020
# Program will wait for a minute and try again.
#
# 600 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/solana/history?date=09-05-2020
# Program will wait for a minute and try again.
#
# 'community_data' | solana has no community data before 10-04-2020. Breaking loop.
# All done for solana.
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/matic-network/history?date=11-01-2022
# Program will wait for a minute and try again.
#
# 100 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/matic-network/history?date=09-11-2021
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/matic-network/history?date=29-08-2021
# Program will wait for a minute and try again.
#
# 200 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/matic-network/history?date=09-06-2021
# Program will wait for a minute and try again.
#
# 300 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/matic-network/history?date=30-03-2021
# Program will wait for a minute and try again.
#
# 400 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/matic-network/history?date=18-01-2021
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/matic-network/history?date=28-10-2020
# Program will wait for a minute and try again.
#
# 500 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/matic-network/history?date=28-08-2020
# Program will wait for a minute and try again.
#
# 600 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/matic-network/history?date=08-06-2020
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/matic-network/history?date=08-04-2020
# Program will wait for a minute and try again.
#
# 700 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/matic-network/history?date=23-01-2020
# Program will wait for a minute and try again.
#
# 800 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/matic-network/history?date=21-11-2019
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/matic-network/history?date=12-09-2019
# Program will wait for a minute and try again.
#
# 900 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/matic-network/history?date=06-07-2019
# Program will wait for a minute and try again.
# 1000 days processed
# 'community_data' | matic-network has no community data before 26-04-2019. Breaking loop.
# All done for matic-network.
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/cardano/history?date=21-02-2022
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/cardano/history?date=05-12-2021
# Program will wait for a minute and try again.
#
# 100 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/cardano/history?date=04-10-2021
# Program will wait for a minute and try again.
#
# 200 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/cardano/history?date=16-07-2021
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/cardano/history?date=16-05-2021
# Program will wait for a minute and try again.
#
# 300 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/cardano/history?date=01-03-2021
# Program will wait for a minute and try again.
#
# 400 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/cardano/history?date=19-12-2020
# Program will wait for a minute and try again.
#
# 500 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/cardano/history?date=27-09-2020
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/cardano/history?date=24-07-2020
# Program will wait for a minute and try again.
#
# 600 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/cardano/history?date=12-05-2020
# Program will wait for a minute and try again.
#
# 700 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/cardano/history?date=11-03-2020
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/cardano/history?date=29-12-2019
# Program will wait for a minute and try again.
#
# 800 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/cardano/history?date=24-10-2019
# Program will wait for a minute and try again.
#
# 900 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/cardano/history?date=15-08-2019
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/cardano/history?date=01-06-2019
# Program will wait for a minute and try again.
#
# 1000 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/cardano/history?date=23-03-2019
# Program will wait for a minute and try again.
#
# All done for cardano.
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/terra-luna/history?date=31-12-2021
# Program will wait for a minute and try again.
#
# 100 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/terra-luna/history?date=02-11-2021
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/terra-luna/history?date=14-08-2021
# Program will wait for a minute and try again.
#
# 200 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/terra-luna/history?date=15-06-2021
# Program will wait for a minute and try again.
#
# 300 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/terra-luna/history?date=28-03-2021
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/terra-luna/history?date=27-01-2021
# Program will wait for a minute and try again.
#
# 400 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/terra-luna/history?date=16-11-2020
# Program will wait for a minute and try again.
#
# 500 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/terra-luna/history?date=12-09-2020
# Program will wait for a minute and try again.
#
# 600 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/terra-luna/history?date=02-07-2020
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/terra-luna/history?date=17-04-2020
# Program will wait for a minute and try again.
#
# 700 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/terra-luna/history?date=10-02-2020
# Program will wait for a minute and try again.
#
# 800 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/terra-luna/history?date=09-11-2019
# Program will wait for a minute and try again.
#
# 900 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/terra-luna/history?date=23-08-2019
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/terra-luna/history?date=17-06-2019
# Program will wait for a minute and try again.
#
# 1000 days processed
# 'community_data' | terra-luna has no community data before 07-05-2019. Breaking loop.
# All done for terra-luna.
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/mirror-protocol/history?date=15-01-2022
# Program will wait for a minute and try again.
#
# 100 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/mirror-protocol/history?date=04-11-2021
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/mirror-protocol/history?date=25-08-2021
# Program will wait for a minute and try again.
#
# 200 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/mirror-protocol/history?date=05-06-2021
# Program will wait for a minute and try again.
#
# 300 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/mirror-protocol/history?date=01-04-2021
# Program will wait for a minute and try again.
#
# 400 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/mirror-protocol/history?date=14-01-2021
# Program will wait for a minute and try again.
#
# 'community_data' | mirror-protocol has no community data before 03-12-2020. Breaking loop.
# All done for mirror-protocol.
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/aave/history?date=16-01-2022
# Program will wait for a minute and try again.
#
# 520 Server Error:  for url: https://api.coingecko.com/api/v3/coins/aave/history?date=05-01-2022
# Program will wait for a minute and try again.
#
# 100 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/aave/history?date=16-10-2021
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/aave/history?date=09-08-2021
# Program will wait for a minute and try again.
#
# 200 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/aave/history?date=24-05-2021
# Program will wait for a minute and try again.
#
# 300 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/aave/history?date=26-03-2021
# Program will wait for a minute and try again.
#
# 400 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/aave/history?date=09-01-2021
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/aave/history?date=12-11-2020
# Program will wait for a minute and try again.
# 500 days processed
# 'community_data' | aave has no community data before 02-10-2020. Breaking loop.
# All done for aave.
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/avalanche-2/history?date=22-01-2022
# Program will wait for a minute and try again.
#
# 100 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/avalanche-2/history?date=07-11-2021
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/avalanche-2/history?date=03-09-2021
# Program will wait for a minute and try again.
#
# 200 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/avalanche-2/history?date=17-06-2021
# Program will wait for a minute and try again.
#
# 300 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/avalanche-2/history?date=16-04-2021
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/avalanche-2/history?date=04-02-2021
# Program will wait for a minute and try again.
#
# 400 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/avalanche-2/history?date=14-11-2020
# Program will wait for a minute and try again.
#
# 500 days processed
# 'community_data' | avalanche-2 has no community data before 21-09-2020. Breaking loop.
# All done for avalanche-2.
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ftx-token/history?date=17-02-2022
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ftx-token/history?date=08-12-2021
# Program will wait for a minute and try again.
#
# 100 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ftx-token/history?date=27-09-2021
# Program will wait for a minute and try again.
#
# 200 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ftx-token/history?date=20-07-2021
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ftx-token/history?date=09-05-2021
# Program will wait for a minute and try again.
#
# 300 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ftx-token/history?date=24-02-2021
# Program will wait for a minute and try again.
#
# 400 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ftx-token/history?date=18-12-2020
# Program will wait for a minute and try again.
#
# 500 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ftx-token/history?date=05-10-2020
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ftx-token/history?date=18-07-2020
# Program will wait for a minute and try again.
#
# 600 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ftx-token/history?date=14-05-2020
# Program will wait for a minute and try again.
#
# 700 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ftx-token/history?date=05-03-2020
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ftx-token/history?date=28-12-2019
# Program will wait for a minute and try again.
#
# 800 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ftx-token/history?date=16-10-2019
# Program will wait for a minute and try again.
#
# 900 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ftx-token/history?date=01-08-2019
# Program will wait for a minute and try again.
#
# 'community_data' | ftx-token has no community data before 29-07-2019. Breaking loop.
# All done for ftx-token.
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/arweave/history?date=24-12-2021
# Program will wait for a minute and try again.
#
# 100 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/arweave/history?date=02-10-2021
# Program will wait for a minute and try again.
#
# 200 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/arweave/history?date=17-07-2021
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/arweave/history?date=14-05-2021
# Program will wait for a minute and try again.
#
# 300 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/arweave/history?date=24-02-2021
# Program will wait for a minute and try again.
#
# 400 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/arweave/history?date=27-12-2020
# Program will wait for a minute and try again.
#
# 500 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/arweave/history?date=08-10-2020
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/arweave/history?date=13-08-2020
# Program will wait for a minute and try again.
#
# 600 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/arweave/history?date=25-05-2020
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/arweave/history?date=28-03-2020
# Program will wait for a minute and try again.
#
# 700 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/arweave/history?date=10-01-2020
# Program will wait for a minute and try again.
#
# 800 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/arweave/history?date=04-11-2019
# Program will wait for a minute and try again.
#
# 'community_data' | arweave has no community data before 31-10-2019. Breaking loop.
# All done for arweave.
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/polkadot/history?date=18-12-2021
# Program will wait for a minute and try again.
#
# 100 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/polkadot/history?date=06-10-2021
# Program will wait for a minute and try again.
#
# 200 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/polkadot/history?date=20-07-2021
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/polkadot/history?date=16-05-2021
# Program will wait for a minute and try again.
#
# 300 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/polkadot/history?date=26-02-2021
# Program will wait for a minute and try again.
#
# 400 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/polkadot/history?date=28-12-2020
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/polkadot/history?date=15-10-2020
# Program will wait for a minute and try again.
#
# 500 days processed
# 'community_data' | polkadot has no community data before 18-08-2020. Breaking loop.
# All done for polkadot.
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/fantom/history?date=21-02-2022
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/fantom/history?date=10-12-2021
# Program will wait for a minute and try again.
#
# 100 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/fantom/history?date=06-10-2021
# Program will wait for a minute and try again.
# 200 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/fantom/history?date=25-07-2021
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/fantom/history?date=06-05-2021
# Program will wait for a minute and try again.
#
# 300 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/fantom/history?date=22-02-2021
# Program will wait for a minute and try again.
#
# 400 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/fantom/history?date=09-12-2020
# Program will wait for a minute and try again.
#
# 500 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/fantom/history?date=29-09-2020
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/fantom/history?date=17-07-2020
# Program will wait for a minute and try again.
#
# 600 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/fantom/history?date=26-04-2020
# Program will wait for a minute and try again.
#
# 700 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/fantom/history?date=26-02-2020
# Program will wait for a minute and try again.
#
# 800 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/fantom/history?date=11-12-2019
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/fantom/history?date=05-10-2019
# Program will wait for a minute and try again.
#
# 900 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/fantom/history?date=25-07-2019
# Program will wait for a minute and try again.
#
# 1000 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/fantom/history?date=05-05-2019
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/fantom/history?date=05-03-2019
# Program will wait for a minute and try again.
#
# All done for fantom.
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/thorchain/history?date=16-12-2021
# Program will wait for a minute and try again.
#
# 100 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/thorchain/history?date=16-10-2021
# Program will wait for a minute and try again.
#
# 200 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/thorchain/history?date=01-08-2021
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/thorchain/history?date=19-05-2021
# Program will wait for a minute and try again.
#
# 300 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/thorchain/history?date=08-03-2021
# Program will wait for a minute and try again.
#
# 400 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/thorchain/history?date=14-12-2020
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/thorchain/history?date=11-10-2020
# Program will wait for a minute and try again.
#
# 500 days processed
# 504 Server Error: Gateway Time-out for url: https://api.coingecko.com/api/v3/coins/thorchain/history?date=30-07-2020
# Program will wait for a minute and try again.
#
# 600 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/thorchain/history?date=21-04-2020
# Program will wait for a minute and try again.
#
# 700 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/thorchain/history?date=20-01-2020
# Program will wait for a minute and try again.
#
# 800 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/thorchain/history?date=04-11-2019
# Program will wait for a minute and try again.
#
# 900 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/thorchain/history?date=28-08-2019
# Program will wait for a minute and try again.
#
# 'community_data' | thorchain has no community data before 20-07-2019. Breaking loop.
# All done for thorchain.

# %% [markdown]
# ### Only for ethereum (substituting omni) | Also, test for possible adds

# %%
extractAll(['ethereum'])
# Out:
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ethereum/history?date=21-12-2021
# Program will wait for a minute and try again.
#
# 100 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ethereum/history?date=01-10-2021
# Program will wait for a minute and try again.
#
# 200 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ethereum/history?date=23-07-2021
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ethereum/history?date=14-05-2021
# Program will wait for a minute and try again.
#
# 300 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ethereum/history?date=27-02-2021
# Program will wait for a minute and try again.
#
# 400 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ethereum/history?date=22-12-2020
# Program will wait for a minute and try again.
#
# 500 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ethereum/history?date=01-10-2020
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ethereum/history?date=01-08-2020
# Program will wait for a minute and try again.
#
# 600 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ethereum/history?date=19-05-2020
# Program will wait for a minute and try again.
#
# 700 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ethereum/history?date=19-03-2020
# Program will wait for a minute and try again.
#
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ethereum/history?date=08-01-2020
# Program will wait for a minute and try again.
#
# 800 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ethereum/history?date=07-11-2019
# Program will wait for a minute and try again.
#
# ('Connection aborted.', OSError("(65, 'EHOSTUNREACH')"))
# Program will wait for a minute and try again.
#
# 900 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ethereum/history?date=04-08-2019
# Program will wait for a minute and try again.
#
# 1000 days processed
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ethereum/history?date=12-05-2019
# Program will wait for a minute and try again.
#
# All done for ethereum.
#            bytes
# ethereum  248597

# %% [markdown]
# **Check Results**

# %%
c98 = pd.read_csv('ts_CSVs/coin98_daily_data.csv', index_col = 'Unnamed: 0')

# Check end of the time series
c98.tail(50)
# Out:
#             twitter_followers  reddit_subs  reddit_avg_posts_48h  \
# 14-04-2019                NaN          NaN                   NaN
# 20-03-2019            NaN               NaN                        NaN
# 19-03-2019            NaN               NaN                        NaN
# 18-03-2019            NaN               NaN                        NaN
# 17-03-2019            NaN               NaN                        NaN
# 16-03-2019            NaN               NaN                        NaN
# 15-03-2019            NaN               NaN                        NaN
# 14-03-2019            NaN               NaN                        NaN
# 13-03-2019            NaN               NaN                        NaN
# 12-03-2019            NaN               NaN                        NaN
# 11-03-2019            NaN               NaN                        NaN
# 10-03-2019            NaN               NaN                        NaN
# 09-03-2019            NaN               NaN                        NaN
# 08-03-2019            NaN               NaN                        NaN
# 07-03-2019            NaN               NaN                        NaN
# 06-03-2019            NaN               NaN                        NaN
# 05-03-2019            NaN               NaN                        NaN
# 04-03-2019            NaN               NaN                        NaN
# 03-03-2019            NaN               NaN                        NaN
# 02-03-2019            NaN               NaN                        NaN
# 01-03-2019            NaN               NaN                        NaN
# 28-02-2019            NaN               NaN                        NaN
# 27-02-2019            NaN               NaN                        NaN
# 26-02-2019            NaN               NaN                        NaN
# 25-02-2019            NaN               NaN                        NaN
# 24-02-2019            NaN               NaN                        NaN
#
#             usd_cp  eur_cp  brl_cp  usd_mc  eur_mc  brl_mc  usd_tv  eur_tv  \
# 14-04-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 13-04-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 12-04-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 11-04-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 10-04-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 09-04-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 08-04-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 07-04-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 06-04-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 05-04-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 04-04-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 03-04-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 02-04-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 01-04-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 31-03-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 30-03-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 29-03-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 28-03-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 27-03-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 26-03-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 25-03-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 24-03-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 23-03-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 22-03-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 21-03-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 20-03-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 19-03-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 18-03-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 17-03-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 16-03-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 15-03-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 14-03-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 13-03-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 12-03-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 11-03-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 10-03-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 09-03-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 08-03-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 07-03-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 06-03-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 05-03-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 04-03-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 03-03-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 02-03-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 01-03-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 28-02-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 27-02-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 26-02-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 25-02-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 24-02-2019     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#             brl_tv
# 14-04-2019     NaN
# 13-04-2019     NaN
# 12-04-2019     NaN
# 11-04-2019     NaN
# 10-04-2019     NaN
# 09-04-2019     NaN
# 08-04-2019     NaN
# 07-04-2019     NaN
# 06-04-2019     NaN
# 05-04-2019     NaN
# 04-04-2019     NaN
# 03-04-2019     NaN
# 02-04-2019     NaN
# 01-04-2019     NaN
# 31-03-2019     NaN
# 30-03-2019     NaN
# 29-03-2019     NaN
# 28-03-2019     NaN
# 27-03-2019     NaN
# 26-03-2019     NaN
# 25-03-2019     NaN
# 24-03-2019     NaN
# 23-03-2019     NaN
# 22-03-2019     NaN
# 21-03-2019     NaN
# 20-03-2019     NaN
# 19-03-2019     NaN
# 18-03-2019     NaN
# 17-03-2019     NaN
# 16-03-2019     NaN
# 15-03-2019     NaN
# 14-03-2019     NaN
# 13-03-2019     NaN
# 12-03-2019     NaN
# 11-03-2019     NaN
# 10-03-2019     NaN
# 09-03-2019     NaN
# 08-03-2019     NaN
# 07-03-2019     NaN
# 06-03-2019     NaN
# 05-03-2019     NaN
# 04-03-2019     NaN
# 03-03-2019     NaN
# 02-03-2019     NaN
# 01-03-2019     NaN
# 28-02-2019     NaN
# 27-02-2019     NaN
# 26-02-2019     NaN
# 25-02-2019     NaN
# 24-02-2019     NaN

# %% [markdown]
# * As we can see, **the API is not perfect**.
# * It fails to retrieve 'twitter_followers' data for some dates and have no access to some projects GitHub account.
# * In the next step (**script** | csv_final_prep), we'll handle missing data, whilst making sure our time series stays intact.
