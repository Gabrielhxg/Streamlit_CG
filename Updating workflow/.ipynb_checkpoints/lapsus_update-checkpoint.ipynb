# %%
### Requirements ### 
import pandas as pd
import numpy as np 
import time
import sys

import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime, timedelta 
from pycoingecko import CoinGeckoAPI
cg = CoinGeckoAPI()

### Function defined in other file ###
import ipynb.fs  
from .defs.preOperations import tsMaker

# %% [markdown]
# # Collect and Store
# * By this time, we have locally accumulated 3 years of daily data, which required 14 hours of API request-handling process
# * This script was used during-development, with the simple objective of updating the lastest version of all time-series as days went by | So we dont need the 14-hours-process again.
#
#
#
# ## 2nd | Network lapsus update
#
# ### Defining network lapsus updating function
# * **Approach 1** | Test for 3 ids
# * **Objectives** | create Xdays-df to be concatenated to coins final_CSV version (**'treated_CSVs' folder** | created in the 'Database building workflow' last script)

# %%
def tsLapsus(ids, days):
    
    '''
    Takes an array of ids, request up to 100 days/min worth of social media, github and market data from coingeckoAPI().
    Read outdated CSVs, concat collected data into new, updated CSVs and export it to a new folder. 
    
    : tsLapsus('bitcoin', 10)
    > df([features], index = days range)
    '''
    
    ############ Create updated df #######################
    
    for id in ids.id:
        
        # Call the tsMaker function from preOperations.ipynb
        ts_df = tsMaker(id, days)
        
        # Interpolate
        ts_df.interpolate(inplace=True)

        # backfill first entry if there's any NaN
        ts_df.fillna(method='bfill', inplace=True)
        
        # Reset index to 'dates' columns
        ts_df.reset_index(inplace = True)
        ts_df.rename(columns={'index': 'dates'}, inplace=True)
        
    ############### Concat Part #######################
        
        # Read outdated csvs 
        from_path = f'/Users/gabrielgomes/ProjetoAwariCripto/Updating workflow/treated_CSVs/{id}_final.csv'
        out_dated = pd.read_csv(from_path).drop(columns=['Unnamed: 0'])
        
        # Updated data
        up_dated = pd.concat([ts_df, out_dated])
        
        # Updated CSVs download
        to_path = f'/Users/gabrielgomes/ProjetoAwariCripto/Updating workflow/updated_CSVs/{id}_updated.csv'
        up_dated.to_csv(to_path)
        
        # Communicate
        print(f'{id}_updated is in the updated_CSVs file.')
        
    return up_dated

# %% [markdown]
# ### Simulations

# %%
# Create folder for updated CSVs
import os  
os.makedirs('updated_CSVs', exist_ok = True)

# %%
ids=pd.read_csv('main50.csv', index_col = 'Unnamed: 0')

# %%
rem_ids = ids[9:]

# %% [markdown]
# ### For real

# %%
tsLapsus(rem_ids, 33)
# Out:
# All done for stellar.
# stellar_updated is in the updated_CSVs file.
# All done for chainlink.
# chainlink_updated is in the updated_CSVs file.
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/steem/history?date=25-03-2022
# Program will wait for a minute and try again.
#
# All done for steem.
# steem_updated is in the updated_CSVs file.
# All done for steem-dollars.
# steem-dollars_updated is in the updated_CSVs file.
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/dash/history?date=10-03-2022
# Program will wait for a minute and try again.
#
# All done for dash.
# dash_updated is in the updated_CSVs file.
# All done for verge.
# verge_updated is in the updated_CSVs file.
# All done for the-graph.
# the-graph_updated is in the updated_CSVs file.
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/hiveterminal/history?date=27-03-2022
# Program will wait for a minute and try again.
#
# All done for hiveterminal.
# hiveterminal_updated is in the updated_CSVs file.
# All done for bytom.
# bytom_updated is in the updated_CSVs file.
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/storj/history?date=13-03-2022
# Program will wait for a minute and try again.
#
# All done for storj.
# storj_updated is in the updated_CSVs file.
# All done for bitshares.
# bitshares_updated is in the updated_CSVs file.
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/compound-yearn-finance/history?date=14-03-2022
# Program will wait for a minute and try again.
#
# All done for compound-yearn-finance.
# compound-yearn-finance_updated is in the updated_CSVs file.
# All done for peercoin.
# peercoin_updated is in the updated_CSVs file.
# All done for aelf.
# aelf_updated is in the updated_CSVs file.
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/mina-protocol/history?date=03-04-2022
# Program will wait for a minute and try again.
#
# All done for mina-protocol.
# mina-protocol_updated is in the updated_CSVs file.
# All done for aeternity.
# aeternity_updated is in the updated_CSVs file.
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/dragonchain/history?date=19-03-2022
# Program will wait for a minute and try again.
#
# All done for dragonchain.
# dragonchain_updated is in the updated_CSVs file.
# All done for vechain.
# vechain_updated is in the updated_CSVs file.
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/skycoin/history?date=04-03-2022
# Program will wait for a minute and try again.
#
# All done for skycoin.
# skycoin_updated is in the updated_CSVs file.
# All done for augur.
# augur_updated is in the updated_CSVs file.
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/gridcoin-research/history?date=04-03-2022
# Program will wait for a minute and try again.
#
# All done for gridcoin-research.
# gridcoin-research_updated is in the updated_CSVs file.
# All done for aragon.
# aragon_updated is in the updated_CSVs file.
# All done for ark.
# ark_updated is in the updated_CSVs file.
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/ethereum/history?date=30-03-2022
# Program will wait for a minute and try again.
#
# All done for ethereum.
# ethereum_updated is in the updated_CSVs file.
# All done for electroneum.
# electroneum_updated is in the updated_CSVs file.
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/tornado-cash/history?date=07-03-2022
# Program will wait for a minute and try again.
#
# All done for tornado-cash.
# tornado-cash_updated is in the updated_CSVs file.
# All done for platon-network.
# platon-network_updated is in the updated_CSVs file.
# All done for eos.
# eos_updated is in the updated_CSVs file.
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/coin98/history?date=25-03-2022
# Program will wait for a minute and try again.
#
# All done for coin98.
# coin98_updated is in the updated_CSVs file.
# All done for solana.
# solana_updated is in the updated_CSVs file.
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/matic-network/history?date=21-03-2022
# Program will wait for a minute and try again.
#
# All done for matic-network.
# matic-network_updated is in the updated_CSVs file.
# All done for cardano.
# cardano_updated is in the updated_CSVs file.
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/terra-luna/history?date=16-03-2022
# Program will wait for a minute and try again.
#
# All done for terra-luna.
# terra-luna_updated is in the updated_CSVs file.
# All done for mirror-protocol.
# mirror-protocol_updated is in the updated_CSVs file.
# All done for aave.
# aave_updated is in the updated_CSVs file.
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/avalanche-2/history?date=31-03-2022
# Program will wait for a minute and try again.
#
# All done for avalanche-2.
# avalanche-2_updated is in the updated_CSVs file.
# All done for ftx-token.
# ftx-token_updated is in the updated_CSVs file.
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/arweave/history?date=03-04-2022
# Program will wait for a minute and try again.
#
# All done for arweave.
# arweave_updated is in the updated_CSVs file.
# All done for polkadot.
# polkadot_updated is in the updated_CSVs file.
# 429 Client Error: Too Many Requests for url: https://api.coingecko.com/api/v3/coins/fantom/history?date=29-03-2022
# Program will wait for a minute and try again.
#
# All done for fantom.
# fantom_updated is in the updated_CSVs file.
# All done for thorchain.
# thorchain_updated is in the updated_CSVs file.
#            dates  twitter_followers  reddit_subs  reddit_avg_posts_48h  \
# 0     03-04-2022      159524.000000      10658.0                  0.60
# 1     02-04-2022      159204.000000      10639.0                  1.44
# 2     01-04-2022      158800.666667      10628.0                  1.22
# 3     31-03-2022      158397.333333      10605.0                  1.56
# 4     30-03-2022      157994.000000      10563.0                  1.40
# ...          ...                ...          ...                   ...
# 1090  28-02-2019        4766.000000       1406.0                  0.00
# 1091  27-02-2019        4766.000000       1406.0                  0.00
# 1092  26-02-2019        4766.000000       1406.0                  0.00
# 1093  25-02-2019        4766.000000       1406.0                  0.00
# 1094  24-02-2019        4766.000000       1406.0                  0.00
#
#       reddit_avg_comments_48h  forks  stars  github_subs  total_issues  \
# 0                        5.80    1.0    0.0          2.0           0.0
# 1                       10.89    1.0    0.0          2.0           0.0
# 2                       14.11    1.0    0.0          2.0           0.0
# 3                       15.11    1.0    0.0          2.0           0.0
# 4                       10.60    1.0    0.0          2.0           0.0
# ...                       ...    ...    ...          ...           ...
# 1090                     0.00    7.0   25.0         13.0           0.0
# 1091                     0.00    7.0   25.0         13.0           0.0
# 1092                     0.00    7.0   25.0         13.0           0.0
# 1093                     0.00    7.0   25.0         13.0           0.0
# 1094                     0.00    7.0   25.0         13.0           0.0
#
#       closed_issues  ...  pull_request_contributors  usd_cp  eur_cp  brl_cp  \
# 0               0.0  ...                        3.0   11.45   10.37   53.36
# 1               0.0  ...                        3.0   12.42   11.24   57.85
# 2               0.0  ...                        3.0   11.44   10.33   54.23
# 3               0.0  ...                        3.0   11.96   10.72   57.06
# 4               0.0  ...                        3.0   11.90   10.73   56.61
# ...             ...  ...                        ...     ...     ...     ...
# 1090            0.0  ...                        3.0    0.03    0.02    0.10
# 1091            0.0  ...                        3.0    0.03    0.02    0.10
# 1092            0.0  ...                        3.0    0.03    0.02    0.10
# 1093            0.0  ...                        3.0    0.03    0.02    0.10
# 1094            0.0  ...                        3.0    0.03    0.02    0.10
#
#             usd_mc        eur_mc        brl_mc       usd_tv       eur_tv  \
# 0     3.452665e+09  3.125998e+09  1.609223e+10  212641323.0  192522689.0
# 1     3.737113e+09  3.382461e+09  1.741079e+10  343190689.0  310621893.0
# 2     3.426232e+09  3.094360e+09  1.623794e+10  479296986.0  432836333.0
# 3     3.610861e+09  3.235996e+09  1.722850e+10  351805759.0  315237310.0
# 4     3.567777e+09  3.216601e+09  1.697441e+10  526412547.0  474617237.0
# ...            ...           ...           ...          ...          ...
# 1090  1.184196e+06  1.054728e+06  4.439433e+06     847137.0     754520.0
# 1091  1.184196e+06  1.054728e+06  4.439433e+06     847137.0     754520.0
# 1092  1.184196e+06  1.054728e+06  4.439433e+06     847137.0     754520.0
# 1093  1.184196e+06  1.054728e+06  4.439433e+06     847137.0     754520.0
# 1094  1.184196e+06  1.054728e+06  4.439433e+06     847137.0     754520.0
#
#             brl_tv
# 0     9.910814e+08
# 1     1.598887e+09
# 2     2.271532e+09
# 3     1.678536e+09
# 4     2.504513e+09
# ...            ...
# 1090  3.175834e+06
# 1091  3.175834e+06
# 1092  3.175834e+06
# 1093  3.175834e+06
# 1094  3.175834e+06
#
# [1128 rows x 21 columns]

# %% [markdown]
# ## What we've done
# * **Our previous workflow** retrieved 1095 days of daily metrics, from February-2019 to February-2022
# * As the deployment of this database will be finallized latter, tsLapsus(ids, days) localizes the work only to needed dates.
